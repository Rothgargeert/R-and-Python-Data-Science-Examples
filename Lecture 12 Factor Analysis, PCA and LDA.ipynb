# %%
#Factor Analysis; personality text data
import pandas as pd
dat = pd.read_csv('personality0.txt', sep=" ") 
dat
# Out:
#      distant  talkatv  carelss  hardwrk  anxious  agreebl  tense  kind  \
# 1          2        7        1        4        7        8      5     9
# 2          3        8        2        7        5        8      4     8
# 3          6        6        2        5        1        8      2     9
# 4          3        7        6        7        8        8      2     8
# 5          7        3        3        5        8        6      7     2
# ..       ...      ...      ...      ...      ...      ...    ...   ...
# 236        3        6        3        7        5        6      4     7
# 237        2        8        3        7        2        7      2     7
# 238        4        9        3        9        7        7      5     7
# 239        3        8        4        9        7        6      5     6
# 240        8        6        7        7        9        9      9     6
#
#      opposng  relaxed  ...  lazy  coopera  quiet  organiz  criticl  lax  \
# 1          5        6  ...     7        9      9        5        5    5
# 2          5        7  ...     2        7      6        6        4    3
# 3          2        8  ...     5        8      7        4        5    5
# 4          3        7  ...     3        8      4        7        6    6
# 5          3        3  ...     6        6      7        5        5    3
# ..       ...      ...  ...   ...      ...    ...      ...      ...  ...
# 236        3        7  ...     4        7      4        7        5    5
# 237        2        8  ...     4        6      4        7        2    4
# 238        5        5  ...     3        5      2        7        3    3
# 239        3        5  ...     1        6      5        7        5    2
# 240        8        4  ...     6        8      8        3        9    3
#
#      laidbck  withdrw  givinup  easygon
# 1          7        5        5        8
# 2          7        2        2        7
# 3          7        6        2        8
# 4          6        4        3        7
# 5          3        7        5        5
# ..       ...      ...      ...      ...
# 236        6        6        3        7
# 237        7        3        2        7
# 238        7        2        1        6
# 239        5        3        2        7
# 240        1        7        3        3
#
# [240 rows x 32 columns]

# %%
#Correlogram
import matplotlib.pyplot as plt
import numpy as np
corr = dat.corr() 
fig = plt.figure() 
ax = fig.add_subplot(111) 
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1) 
fig.colorbar(cax) 
fig.set_size_inches([16,16]) 
ticks = np.arange(0,len(dat.columns),1) 
ax.set_xticks(ticks) 
plt.xticks(rotation=90) 
ax.set_yticks(ticks) 
ax.set_xticklabels(dat.columns) 
ax.set_yticklabels(dat.columns) 
plt.show()

# %%
#Factor analysis
from sklearn.preprocessing import scale 
from sklearn.decomposition import FactorAnalysis
data_normal = scale(dat) 
fa = FactorAnalysis(n_components = 10) 
fa = fa.fit(data_normal)

# %%
feature_names = dat.columns 
factor_names = ['Factor'+str(x) for x in range(1,11)] 
pd.DataFrame(np.transpose(fa.components_), index=feature_names , 
             columns=factor_names)
# Out:
#           Factor1   Factor2   Factor3   Factor4   Factor5   Factor6   Factor7  \
# distant  0.611485 -0.151593 -0.128730  0.058590  0.251456 -0.142079  0.072521
# talkatv -0.534784  0.258231  0.504032  0.023324  0.094551  0.018232 -0.012701
# carelss  0.424031  0.455278  0.289612 -0.091191  0.105853 -0.167724  0.038255
# hardwrk -0.410909 -0.513731  0.125005  0.008189  0.202946 -0.270491  0.170538
# anxious  0.378685 -0.329434  0.408118 -0.436334  0.072310  0.059724  0.191798
# agreebl -0.262128  0.125649 -0.211000 -0.593456  0.210000 -0.062669 -0.089723
# tense    0.417604 -0.431759  0.491742 -0.316223  0.014092  0.046168  0.144372
# kind    -0.444516 -0.178681 -0.171324 -0.486450  0.154772  0.038279 -0.220072
# opposng  0.280536  0.008495  0.405173  0.217041  0.399764  0.110692 -0.243947
# relaxed -0.277459  0.484012 -0.464172  0.001707  0.290768  0.038104 -0.020929
# disorgn  0.395919  0.667652  0.239915 -0.183660  0.014957 -0.304860 -0.045436
# outgoin -0.717864  0.209519  0.415262 -0.047016  0.045694  0.069308  0.089875
# approvn -0.468064  0.076304 -0.065532 -0.321731  0.164767  0.008576  0.035295
# shy      0.646214 -0.135098 -0.370064 -0.212089 -0.073907  0.078917 -0.061853
# discipl -0.254286 -0.525061 -0.070422  0.045181  0.228492 -0.336387  0.140401
# harsh    0.367884  0.001059  0.353362  0.303903  0.393674  0.020722 -0.130721
# persevr -0.363649 -0.406171  0.089672 -0.073737  0.202516 -0.311276  0.001734
# friendl -0.631561  0.034684  0.142127 -0.429836  0.059646  0.043720 -0.098610
# worryin  0.389893 -0.384144  0.395476 -0.377764 -0.084453  0.135358  0.087384
# respnsi -0.392062 -0.576175 -0.110202 -0.072438  0.198937 -0.133508 -0.151190
# contrar  0.384076 -0.019138  0.429802  0.214145  0.405734  0.096690 -0.172487
# sociabl -0.649653  0.272576  0.286548 -0.121552 -0.022385  0.186832 -0.034815
# lazy     0.496019  0.422396  0.085294 -0.160200 -0.000763  0.331964 -0.059049
# coopera -0.428177 -0.001133 -0.252346 -0.436150  0.060186 -0.083305 -0.182814
# quiet    0.627225 -0.223287 -0.397837 -0.299830  0.098024  0.072159 -0.088079
# organiz -0.472140 -0.651013 -0.170923  0.152085  0.115870  0.263038  0.046871
# criticl  0.205984 -0.274805  0.278759  0.212084  0.381157  0.111480 -0.200883
# lax      0.138170  0.477133 -0.067276 -0.139304  0.186488  0.147910  0.089366
# laidbck -0.142549  0.534927 -0.320708  0.026586  0.428330  0.102507  0.331464
# withdrw  0.744630 -0.176072 -0.204427 -0.004556  0.225700 -0.060425  0.060470
# givinup  0.610481  0.114912  0.061999 -0.094520 -0.023526  0.251157  0.089442
# easygon -0.301377  0.388587 -0.249898 -0.139607  0.295942  0.168448  0.111136
#
#           Factor8   Factor9  Factor10
# distant -0.055712 -0.191163 -0.260306
# talkatv -0.058536 -0.049741  0.113394
# carelss -0.081022 -0.060276  0.134460
# hardwrk  0.043005 -0.026847  0.188853
# anxious -0.059215  0.062405 -0.054182
# agreebl -0.370019  0.116346 -0.049258
# tense   -0.032358  0.138997 -0.031827
# kind     0.040844 -0.079402  0.005615
# opposng  0.091602  0.105811 -0.180274
# relaxed  0.051508  0.121283 -0.000905
# disorgn  0.084112  0.026479  0.004802
# outgoin  0.000162 -0.131022 -0.068525
# approvn -0.088175 -0.030155  0.016778
# shy      0.155699  0.037221  0.174236
# discipl -0.020347  0.094459  0.171147
# harsh   -0.199662  0.043055  0.212794
# persevr  0.229709 -0.100883  0.011482
# friendl  0.185716 -0.149780  0.062052
# worryin  0.181274  0.028740 -0.054009
# respnsi  0.064466  0.040056 -0.091180
# contrar  0.040800 -0.018629 -0.018439
# sociabl  0.047278 -0.020884  0.101738
# lazy     0.022123 -0.006990  0.116101
# coopera -0.098548 -0.076564 -0.014728
# quiet    0.091458  0.031785  0.046928
# organiz -0.050180 -0.014429  0.038835
# criticl  0.098463  0.049797  0.022039
# lax      0.074358 -0.038576  0.107910
# laidbck  0.111225  0.104646 -0.014334
# withdrw -0.040486 -0.263912  0.019352
# givinup -0.172303 -0.219096  0.085906
# easygon  0.073004 -0.061166 -0.120635

# %%
from sklearn import datasets 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
import matplotlib.pyplot as plt 
from sklearn.decomposition import PCA 
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris() 
X = iris.data # Sepal and pedal negth and width 
y = iris.target 
target_names = iris.target_names 
pca = PCA(n_components=2) 
X_r = pca.fit(X).transform(X) 
lda = LinearDiscriminantAnalysis(n_components=2) 
X_r2 = lda.fit(X, y).transform(X) # Percentage of variance explained for each components 
plt.figure() 

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], color=color, alpha=.8, lw=lw,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA of IRIS dataset')

plt.figure()

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_r2[y == i, 0], X_r2[y == i, 1], alpha=.8, color=color,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('LDA of IRIS dataset')

plt.show()
